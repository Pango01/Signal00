# %% [markdown]
# # **TP II : Les signaux sinusoïdaux**
# -----------------
# + **Cours "Physique du Numérique"** - Portail René Descartes - AMU
#
# Préparé par :
#
# - Jean-Marc Themlin (v. 2021-09), Aix-Marseille Université © Contenus à diffusion restreinte, dans le cadre de ce cours.
#
# ------------------

# %% [markdown]
# Ce TP donne une introduction au traitement des signaux numériques avec Python, en prenant comme exemple les signaux numériques représentant des sons purs, donc des signaux sinusoïdaux de fréquence audible.
#
# ### Méthodologie
#
# Il s'agit d'un TP de type exploratoire, destiné à introduire des outils de manipulation et de traitement des signaux sonores numériques. Vous n'auriez sans doute pas été en mesure de concevoir les scripts Python que vous découvrirez ci-dessous ; en revanche, prenez la peine de regarder de près leurs instructions, pour que vous puissiez vous y référer et vous en inspirer lorsqu'à votre tour vous devrez concevoir ce type de programmes.
#
# D'autre part, vous êtes invités à effectuer les exercices qui suivent chacune des activités ci-dessous, destinées à bien vous faire comprendre la signification et la portée des concepts évoqués au cours. Assurez-vous que vous comprenez le sens de ce que vous faites ; en cas de doute, n'hésitez pas à discuter vos résultats avec votre encadreur.
#
# ### Remarque
# A toutes fins utiles, on rappelle ici qu'une solution de secours (moins pratique, et probablement moins stable) permet d'accéder aux énoncés sur des notebooks fonctionnels sur un serveur distant (Binder) uniquement depuis votre navigateur. Vous pourrez exécuter, modifier et compléter les cellules de code et remplir les cellules de texte ; à l'issue de votre travail, vous pourrez importer (commande `Download` dans le menu *File*) le notebook complété pour le stocker localement sur votre PC et le déposer sur AMeTICE. Pour accéder à Binder pour travailler ce premier TP, il suffit de cliquer sur l'icône ci-dessous et de sélectionner dans le répertoire des fichiers accessibles, le notebook *Enonce_Lab_1_Signaux.ipynb* ; soyez patient, ça peut prendre quelques minutes pour lancer l'environnement :
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/Pango01/conda/HEAD/)
#
# -------------------
#
# ### Remarque importante
# #### Plusieurs scripts ci-dessous permettent d'écouter des signaux sonores générés par l'ordinateur. En séance de TP, veillez à vous munir de vos écouteurs pour ne pas perturber les groupes voisins, ou à défaut d'écouteurs, à maintenir modéré le niveau sonore des sons générés.
#
# --------------------
#
# ## II.0. Introduction : Ondes sinusoïdales
#
# Les **signaux sinusoïdaux** sont les éléments de base de la théorie des signaux et des systèmes, à la fois pour des raisons fondamentales (certaines de leurs combinaisons linéaires peuvent utilisées pour reproduire n'importe quelle forme de signaux - *cf* le chapitre sur la décomposition en série de Fourier) et aussi pratiques (technologiques). On utilise en effet presque toujours des signaux sinusoïdaux (électriques ou optiques) lorsqu'on veut transmettre un message sur un canal de communication (le procédé d'adaptation du signal au canal s'appelle la **modulation**), c'est pourquoi on les désigne également sous le vocable d'**ondes sinusoïdales**.
#
# Les signaux sont donc généralement transmis sous forme d'ondes, par exemple d'ondes électromagnétiques, ondes sinusoïdales qui se propagent dans le vide avec une vitesse égale à celle de la lumière, $v=c=3 \ 10^8 m/s$, et dans les milieux matériels transparents, avec une vitesse moindre dépendant de l'indice de réfraction du milieu, selon $v_{Milieu} = \frac{c}{n_{Milieu}}$ ($n_{Milieu}>1)$.
#
# Dans le domaine du son, une onde sonore sinusoïdale (en abrégé un "son") est une [onde longitudinale](http://blog.soton.ac.uk/soundwaves/files/2013/12/longituddots1.gif) de fréquence unique $f_0$ (dans la gamme $[20Hz,20kHz]$ où l'oreille humaine est sensible) qui se propage dans un milieu, tel que l'air ou l'eau, une vibration qui se propage dans le milieu sous forme de fluctuations périodiques de pression qui résultent du déplacement des molécules qui constituent le milieu.
#
# L'image animée ci-dessous illustre la propagation d'une onde sonore longitudinale émise par une sphère vibrante dans l'air. On y distingue les fronts d'onde marqués par les fluctuations de densité, donc de pression, associées à la propagation de l'onde sonore longitudinale.
#
# ![Soundwave](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fupload.wikimedia.org%2Fwikipedia%2Fcommons%2F8%2F82%2FSpherical_pressure_waves.gif&f=1&nofb=1)
#
# Une onde sinusoïdale est décrite par un modèle mathématique très général qui fait l'objet de l'exercice 1 ci-dessous.

# %% [markdown]
# ## II.1. Onde progressive sinusoïdale : Longueur d'onde (spatiale) et période (temporelle)
#
# Une onde progressive se déplaçant dans un milieu (exemple : le déplacement transverse d'une corde vibrante, ou une onde sonore longitudinale se propageant dans l'air) peut être décrite (modélisée), le long d'un axe donnant la coordonnée x, par une quantité $y$ (par exemple la pression acoustique) dont la valeur dépend de la coordonnée $x$ et du temps $t$, d'expression analytique suivante (pour une direction de propagation de l'onde selon les $x$ croissants) :
#
# $$ y(x,t) = A \ sin(k\ x - \omega \ t ) $$
#
# dont les paramètres sont les grandeurs suivantes :
#
# - **dans le domaine temporel** : trois grandeurs indépendantes du milieu de propagation de l'onde :
#  - $\omega$, la **pulsation** de l'onde, reliée à la **période** (temporelle) $T$ de l'onde par $\omega = \frac{2\pi}{T}$, et à la **fréquence** de l'onde $\nu=\frac{1}{T}=\frac{2\pi}{\omega}$,
# - **dans le domaine spatial** : où les grandeurs dépendent de la **vitesse de propagation $v$ de l'onde** dans le milieu :
#  - k, le **vecteur d'onde**, relié à
#  - la longueur d'onde $\lambda$, reliée au vecteur d'onde $k$ par $k=\frac{2\pi}{\lambda}$,
#
# ### Simulation de la propagation de l'onde sinusoïdale progressive
#
# Les figures ci-dessous illustrent la propagation d'une onde progressive sinusoïdale d'amplitude $A=1$ le long de l'axe des x (positifs) et de viesse de propagation $v = 2 m/s$.
#
# - Cette figure est l'équivalent d'un film, qui montre la propagation de l'onde le long de l'axe des x en fonction du temps. On y remarque la propression vers la droite des fronts d'onde (les endroits d'égale amplitude, par exemple un maximum, un minimum, ou un "zéro").
#
# ![](https://raw.githubusercontent.com/Pango01/Signal00/main/animate2.gif)
#
# - Cette figure correspond à une photographie qui fige la déformation du milieu en n temps $t_0$ donné. On déduit la longueur d'onde $\lambda$ en mesurant l'écart entre deux zéros, deux minima ou deux maxima successifs.
#
# ![](https://raw.githubusercontent.com/Pango01/Signal00/main/SigSinLambda.png)
#
# - Cette figure montre les variations de la grandeur y en une coordonnée fixe x=1.5, en fonction du temps. Ces variations sont visibles dans la figure du haut, qui montre le mouvement du point orange en milieu de figure (comme un bouchon flottant sur l'eau d'un étang). On déduit de cette figure la période (temporelle) $T$ des oscillations, dont l'inverse permet aussi d'évaluer la fréquence de l'onde via $\nu=\frac{2 \pi}{\omega} = \frac{1}{T}$.
#
# ![](https://raw.githubusercontent.com/Pango01/Signal00/main/SigSinPeriod.png)
#
# #### Avant de résoudre les exercices et de répondre aux questions ci-dessous, exécutez la cellule suivante afin de charger les bibliothèques dont vous aurez besoin lors de ce TP.

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython
import ipywidgets as widgets
import matplotlib.image as mpimg
import matplotlib.animation as animation
import math
import wave
from scipy.io.wavfile import read,write
from jupyterquiz import display_quiz    # After "pip install -U jupyterquiz" in Anaconda Power Shell
from IPython.display import Audio

# Disable warning messages to avoid distracting the beginners
import warnings
warnings.filterwarnings('ignore')   

# Set common figure parameters
newparams = {'axes.labelsize': 8, 'axes.linewidth': 1, 'savefig.dpi': 200,
             'lines.linewidth': 1, 'figure.figsize': (8, 3),
             'ytick.labelsize': 7, 'xtick.labelsize': 7,
             'ytick.major.pad': 5, 'xtick.major.pad': 5,
             'legend.fontsize': 7, 'legend.frameon': True, 
             'legend.handlelength': 1.5, 'axes.titlesize': 7,}
plt.rcParams.update(newparams)

# %% [markdown]
# ## A vous de jouer !
#
# > **Q1.1** : Ecrivez ci-dessous la relation qui lie la période (temporelle) d'une onde sinusoïdale à sa longueur d'onde (spatiale).
#  **Remarque** : Vous pouvez écrire la réponse en $\LaTeX$ : à toutes fins utiles, voici comment on écrit la relation entre la distance $d$ parcourue par un point matériel se déplaçant à la vitesse constante $v$ pendant un temps $\Delta t$ :
# $$ v = \frac{d}{t}$$
#
# > **Q1.1-R** (votre réponse ici) : La période (temporelle) d'une onde sinusoïdale est liée à sa longueur d'onde (spatiale) par la relation :
#
# > **Q1.2** : En considérant votre précédente réponse, complétez la phrase suivante :
#
# > **Q1.2-R** : La _________ représente l'espace parcouru par un front d'onde (un maximum, un minimum ou un zéro) pendant une _________.
#
# > **Q1.3** : Ecrivez ci-dessous la relation qui lie la longueur d'onde $\lambda$ d'une onde sinusoïdale à sa fréquence $\nu$.
#
# > **Q1.3-R** (votre réponse ici) :
#
# > **Q1.4** : Dans la cellule de code ci-dessous, écrivez un script Python qui calcule et affiche la longueur d'onde $\lambda$ d'une onde sonore de fréquence $\nu = 440 Hz$. On donne les valeurs standard des vitesses de propagation du son dans l'air et dans l'eau, respectivement de 330 m/s et de 1500 m/s.
#
# > **Q1.5** : Complétez la cellule de code ci-dessous afin de tracer la dépendance de la longueur d'onde d'une onde sonore sinusoïdale se déplaçant (a) dans l'air, et (b) dans l'eau, en fonction de la fréquence de l'onde sonore sinusoIdale variant dans la plage $[100Hz,100kHz]$. Comme la fréquence varie beaucoup (sur 4 ordres de grandeur), l'idée est d'utiliser un diagramme logarithmique via l'instruction `plt.loglog(nu,lambda)`. On pourra générer un vecteur (1D-array) de points répartis de façon adaptée à l'échelle logarithmique via l'instruction `np.logspace` (effectuez un `help(np.logspace)` pour connaître les détails de sa syntaxe).

# %%
freq=440    #  fréquence en Hz
vs_air=330   #  Vitesse de propagation du son dans l'air
vs_eau=1500   #  Vitesse de propagation du son dans l'eau
#  à compléter

# %% [markdown]
# ## II.2. Les signaux sinusoïdaux : Génération de sons musicaux
#
# ### II.2.A Génération d'un son musical pur
#
# Contrairement aux accords, un son sinusoïdal pur est composé d'une seule composante fréquentielle. Par exemple, le son correspondant à la note LA (A en notation anglaise) est une onde sonore de fréquence $f_0=440 Hz$, créée par un diapason, un haut-parleur, la corde d'un violon ou un autre instrument ou dispositif qui fait osciller l'air à la fréquence donnée.
#
# Sur un ordinateur, les sons ne sont rien d'autre qu'une suite de chiffres de précision limitée, qu'on peut assimiler à des nombres entiers. Un son donné peut être décrit mathématiquement par un signal analogique sinusoïdal (en abrégé, une sinusoïde) d'expression analytique :
#
# $s(t)=A \ \cos(2πft),$
#
# où A est l'amplitude, f est la fréquence (440 Hz pour la note LA de la gamme de Do) et t, la variable indépendante de cette équation, est le temps.
#
# Dans un ordinateur, $s(t)$ est évalué à des points discrets dans le temps, déterminés par la fréquence d'échantillonnage $f_s=\frac{1}{T_s}$. On désigne le signal numérique dérivé de $s(t)$ par $s[n]=s(nT_s)$. .
#
# ### **Exercices**
#
# > **Q2.1** : Un CD audio ordinaire a une fréquence d'échantillonnage de 44100 Hz. Comme la période d'échantillonnage $T_s$ est l'inverse de la fréquence d'échantillonnage $f_s$, soit $f_s=1/T_s$, calculez la période d'échantillonnage des signaux musicaux stockés sur un CD Audio.
#
# > **Q2.1-R** (votre réponse ici) :
#
# La fonction python ci-dessous vous permet de créer un son musical pur (une portion de sinusoïde, limitée dans le temps) avec une fréquence, une longueur, une amplitude et une fréquence d'échantillonnage spécifiques. Vous pourrez donc écouter un son, et visualiser son contenu sous forme d'un graphe représentant les valeurs des échantillons successifs en fonction de leur indice ou du temps.

# %%
def tone(frequency=440., length=1., amplitude=1., sampleRate=44100., soundType='int8'):
    """ Returns a sine function representing a tune with a given frequency.
    
    :frequency: float/int. Frequency of the tone.
    :length: float/int. Length of the tone in seconds.
    :amplitude: float/int. Amplitude of the tone.
    :sampleRate: float/int. Sampling frequency.
    :soundType: string. Type of the elements in the returned array.
    :returns: float numpy array. Sine function representing the tone.
    """
    t = np.linspace(0,length,math.floor(length*sampleRate))
    data = amplitude*np.sin(2*np.pi*frequency*t)
    return data.astype(soundType)

# Parameters that are being used in the start of this notebook
sampleRate = 44100     # La fréquence d'échantillonnage, celle d'un CD audio ordinaire
                       #
sampwidth = 1          # In bytes. 1 for 8 bit, 2 for 16 bit and 4 for 32 bit
                       #
volumePercent = 50     # Volume percentage
nchannels = 1          # Mono. Only mono works for this notebook

# Some dependent variables
shift = 128 if sampwidth == 1 else 0 # The shift of the 8 bit samples, as explained in the section above.
soundType = 'i' + str(sampwidth)
amplitude = np.iinfo(soundType).min*volumePercent/100.

# Parameters for a A tone lasting 1 second at a sample
frequency = 440
length = 2

# Calculate the sine function for the given parameters
data = tone(frequency, length, amplitude, sampleRate, soundType)
print('data =',data)
print('data max =',max(data))

# Plot the function
plt.plot(data,'.')
plt.xlim([0,1000])
plt.title('Visualization of the A tone')
plt.xlabel('Sample number')
plt.show()

# Open a new .wav-file in "write" mode, set file parameters
# and write to file
data += shift # Shift the samplings if we use 8 bit
with wave.open('Atone.wav', 'w') as file:
    file.setparams((nchannels, sampwidth, sampleRate, 0, 'NONE', ''))
    file.writeframes(data)

# Display the sound file
IPython.display.Audio('Atone.wav')

# %% [markdown]
# ## A vous de jouer !
#
# > **Q2.2** : Que représente la valeur `data max` affichée au-dessus de la figure ? **Indication :** Faites le lien avec les graduations de l'axe des ordonnées (l'axe vertical).
#
# > **Q2.2-R** (votre réponse ici) :
#
# > **Q2.3** : Dans la cellule N-1 ci-dessus, modifiez la variable `Sampwidth`, qui fixe la longueur du code des échantillons sur 8 (*Sampwidth*=1), 16 (*Sampwidth*=2) ou 32 bits (*Sampwidth*=4). Observez les changements sur l'échelle verticale de la figure et la valeur de *data max*. Quelle relation lie la valeur de *data max* avec le nombre de chiffres binaires (bits) codant chaque échantillon ?
#
# > **Q2.3-R** (votre réponse ici) :
#
#
# > **Q2.4** : Modifiez les lignes adéquates du code python de la cellule ci-dessous pour visualiser et écouter les différentes notes de la gamme de Do, dont les fréquences en Hz sont données dans le tableau suivant :
#
#
# |  Do  |  Ré  |  Mi  |  Fa  | Sol  |  La  |  Si  |  Do  |
# | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: |
# |  C   |  D   |  E   |  F   |  G   |  A   |  B   |  C   |
# | 262  | 294  | 330  | 349  | 392  | 440  | 494  | 523  |
#
#
# > **Q2.5** : Complétez les trois lignes adéquates du code python de la cellule ci-dessous afin de générer pendant une durée de 3 secondes l'accord de Do Majeur, formé par la superposition des trois notes Do, Mi, et Sol. **Indication** : Le signal sinusoïdal est généré par la fonction `mytone2`, définie au début de la cellule ci-dessous, que vous pouvez modifier selon les instructions en vous inspirant de la fonction `tone`.

# %%
def tone(frequency=440., length=1., amplitude=1., sampleRate=44100., soundType='int8'):
    """ Returns a sine function representing a tune with a given frequency.
    
    :frequency: float/int. Frequency of the tone.
    :length: float/int. Length of the tone in seconds.
    :amplitude: float/int. Amplitude of the tone.
    :sampleRate: float/int. Sampling frequency.
    :soundType: string. Type of the elements in the returned array.
    :returns: float numpy array. Sine function representing the tone.
    """
    t = np.linspace(0,length,math.floor(length*sampleRate))
    data = amplitude*np.sin(2*np.pi*frequency*t)
    return data.astype(soundType)

def mytone2(frequency,length=1., amplitude=1., sampleRate=44100., soundType='int8'):
    """ Returns a sine function representing a tune with a given frequency.
    
    :frequency: float/int. Frequency of the tone.
    :length: float/int. Length of the tone in seconds.
    :amplitude: float/int. Amplitude of the tone.
    :sampleRate: float/int. Sampling frequency.
    :soundType: string. Type of the elements in the returned array.
    :returns: float numpy array. Sine function representing the tone.
    """

    t = np.linspace(0,length,math.floor(length*sampleRate))
    data=np.zeros(math.floor(length*sampleRate))
                            #    Insérez ici une boucle for !
    data = data + amplitude*(np.sin(2*np.pi*f*t))
    return data.astype(soundType)

# Parameters that are being used in the start of this notebook
sampleRate = 44100     # La fréquence d'échantillonnage, celle d'un CD audio ordinaire
sampwidth = 1          # In bytes. 1 for 8 bit, 2 for 16 bit and 4 for 32 bit
volumePercent = 20     # Volume percentage
nchannels = 1          # Mono. Only mono works for this notebook

# Some dependent variables
shift = 128 if sampwidth == 1 else 0 # The shift of the 8 bit samples, as explained in the section above.
soundType = 'i' + str(sampwidth)
amplitude = np.iinfo(soundType).min*volumePercent/100.

# Parameters for a A tone lasting 1 second at a sample
frequency = [262,____,____]    #  Complétez cette ligne pour obtenir l'accord de Do majeur
length = 2                     #  et changez aussi cette valeur pour adapter la durée du signalS

# Calculate the sine function for the given parameters
data = mytone2(frequency,length, amplitude, sampleRate, soundType)
print('data =',data)
print('data max =',max(data))

# Plot the function
plt.plot(data,'.')
plt.xlim([0,1000])
plt.title("Visualisation de l'accord de Do majeur")
plt.xlabel('Sample number')
plt.show()

# Open a new .wav-file in "write" mode, set file parameters
# and write to file
data += shift # Shift the samplings if we use 8 bit
with wave.open('Atone.wav', 'w') as file:
    file.setparams((nchannels, sampwidth, sampleRate, 0, 'NONE', ''))
    file.writeframes(data)

# Display the sound file
IPython.display.Audio('Atone.wav')

# %% [markdown]
# ### II.2.B Composer une mélodie vous pouvez !
#
# C'est parti pour un petit intermède musical, en exécutant la cellule ci-dessous !

# %%
# Create a "function" to translate from a given tone to its frequency
baseTone = 130.813  # The frequecy of the tone C3, bass C
tones = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'Bb', 'B',
         'Ch','C#h','Dh','D#h','Eh','Fh','F#h','Gh','G#h','Ah','Bbh','Bh']
# And use dictionary comprehension to fill in the frequencies
notes2freq = {tones[i]: baseTone*2**(i/12) for i in range(0,len(tones))}
length=5
sampwidth = 2

# The melody data saved as a list of tuples (note, duration)
l = 2.
notes = [('D',0.083*l),('D',0.083*l),('D',0.083*l),('G',0.5*l),('Dh',0.5*l),('Ch',0.083*l),
         ('B',0.083*l),('A',0.083*l),('Gh',0.5*l),('Dh',0.25*l),('Ch',0.083*l),('B',0.083*l),
         ('A',0.083*l),('Gh',0.5*l),('Dh',0.25*l),('Ch',0.083*l),('B',0.083*l),('Ch',0.083*l),
         ('A',0.5*l),('D',0.167*l),('D',0.083*l),('G',0.5*l),('Dh',0.5*l),('Ch',0.083*l),
         ('B',0.083*l),('A',0.083*l),('Gh',0.5*l),('Dh',0.25*l),('Ch',0.083*l),('B',0.083*l),
         ('A',0.083*l),('Gh',0.5*l),('Dh',0.25*l),('Ch',0.083*l),('B',0.083*l),('Ch',0.083*l),
         ('A',0.5*l),('D',0.167*l),('D',0.083*l),('E',0.375*l),('E',0.125*l),('Ch',0.125*l),
         ('B',0.125*l),('A',0.125*l),('G',0.125*l),('G',0.083*l),('A',0.083*l),('B',0.083*l),
         ('A',0.167*l),('E',0.083*l),('F#',0.25*l),('D',0.167*l),('D',0.083*l),('E',0.375*l),
         ('E',0.125*l),('Ch',0.125*l),('B',0.125*l),('A',0.125*l),('G',0.125*l),
         ('Dh',0.1875*l),('A',0.0625*l),('A',0.5*l),('D',0.167*l),('D',0.083*l),('E',0.375*l),
         ('E',0.125*l),('Ch',0.125*l),('B',0.125*l),('A',0.125*l),('G',0.125*l),('G',0.083*l),
         ('A',0.083*l),('B',0.083*l),('A',0.167*l),('E',0.083*l),('F#',0.25*l),('Dh',0.167*l),
         ('Dh',0.083*l),('Gh',0.125*l),('Fh',0.125*l),('D#h',0.125*l),('Ch',0.125*l),
         ('Bb',0.125*l),('A',0.125*l),('G',0.125*l),('Dh',0.75*l)]

# Create the file data
data = np.array([],dtype=soundType)
for note, duration in notes:
    currentFrequency = notes2freq[note]
    currentTone = tone(currentFrequency, duration, amplitude, sampleRate, soundType)
    data = np.append(data, currentTone)
data += shift
with wave.open('melody.wav','w') as file:
    file.setparams((nchannels, sampwidth, sampleRate, 0, 'NONE', ''))
    file.writeframes(data)

IPython.display.Audio('melody.wav')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eae31f8c9799> in <module>
#      27
#      28 # Create the file data
# ---> 29 data = np.array([],dtype=soundType)
#      30 for note, duration in notes:
#      31     currentFrequency = notes2freq[note]
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## II.3. Somme de sinusoïdes déphasées : Interférences
#
# Nous allons maintenant nous intéresser à la somme de deux sinusoïdes de même fréquence, qui ne diffèrent que par une différence de phase (un déphasage) $\Delta \phi$.
#
# > **Q3.1** : Prouvez que la somme $s(t)$ des deux signaux sinusoïdaux de fréquence $f_0$ désignés par $a(t)= \sin(2\pi f_0t + \phi_a)$ et $b(t)= \sin(2\pi f_0t + \phi_b)$ est un toujours un signal sinusoïdal, de même fréquence $f_0$, et trouvez l'expression de l'amplitude et de la phase de $s(t)$. **Indication** : On rappelle que $\sin a + \sin b = 2 \sin(\frac{a+b}{2}) \cos(\frac{a-b}{2})$ (*cf* remarque 2 ci-dessous).
#
# > **Q3.1-R** (votre réponse ici) :
#
# **Remarque 1** : La somme de deux signaux de même fréquence mais d'amplitudes différentes est plus compliquée à démontrer ; nous y reviendrons dans la section 2, où la somme de deux sinusoïdes de même fréquence sera plus facile à déduire à partir des sinusoïdes exprimées comme des vecteurs tournants grâce aux exponentielle complexes.
#
# **Remarque 2** : La démonstration de cette formule de la trigonométrie est possible par l'intermédiaire des nombres complexes, en appliquant la formule d'Euler $\sin \theta = \frac{e^{j\theta}-e^{-j\theta}}{2j}$ (*cf* Section 2 du cours).
#
# $$
# \begin{align}
# \sin a + \sin b &= \frac{1}{2j} \left( e^{ja}-e^{-ja} \right) + \frac{1}{2j} \left( e^{jb}-e^{-jb} \right) \\
# &= \frac{1}{2j} e^{-jb} \left( e^{j(a+b)}-e^{-j(a-b)} \right) + \frac{1}{2j} e^{-ja} \left( e^{j(a+b)}-e^{j(a-b)} \right) \\
# &= \frac{1}{2j} \left( e^{j(a+b)} \left( e^{-jb} + e^{-ja} \right) \right) - \frac{1}{2j} \left( e^{-ja} + e^{-jb} \right) \\
# &= \frac{1}{2j} \left( e^{-jb} + e^{-ja}  \right)  \left( e^{j(a+b)} -1 \right) \\
# &= \frac{1}{2j} \left( e^{-jb} + e^{-ja}  \right) e^{j\frac{a+b}{2}} \left( e^{j\frac{a+b}{2}} - e^{j\frac{a+b}{2}} \right) \\
# &= \frac{1}{2j} \left(  e^{j\frac{a-b}{2}} +  e^{-j\frac{a-b}{2}}  \right)  \left( e^{j\frac{a+b}{2}} - e^{j\frac{a+b}{2}} \right) \\
# &= 2 \frac{e^{j\frac{a-b}{2}} +  e^{-j\frac{a-b}{2}} }{2}  \frac {e^{j\frac{a+b}{2}} - e^{j\frac{a+b}{2}}}{2j} \\
# &= 2 \sin(\frac{a+b}{2}) \cos(\frac{a-b}{2})
# \end{align}
# $$

# %% [markdown]
# ### Simulation
#
# Dans la cellule de code ci-dessous, représentez deux portions de sinusoïdes de même fréquence $f_0$ affectées d'un déphasage $\Delta \phi$, ainsi que leur somme.

# %% [markdown]
# **Amélioration de l'interface homme-machine (IHM) avec une figure interactive** : Vous allez apprendre à utiliser un [*widget* Jupyter](https://ipywidgets.readthedocs.io/en/latest/index.html) pour fixer la valeur du déphasage à l'aide d'un curseur qui va rendre la figure dynamique. A cet effet, complétez la cellule ci-dessous en y incluant des morceaux de votre programme précédent, de manière à inclure la définition du signal déphasé y et de la somme x+y à l'intérieur de la fonction `phase(phi)`. Les deux dernières instructions devraient faire apparaître un curseur avec lequel vous pourrez fixer la valeur du déphasage dans l'intervalle $[-2\pi,2\pi]$, par pas de $\frac{\pi}{16}$.

# %%
# paramètres généraux

    #  à compléter !

t=    #  à compléter !
x=

def phase(phi):
    x=    #  à compléter !
    y=    #  à compléter !
    xy=x+y    #  à compléter !
    #  à compléter avec les instructions de tracé de la figure
    plt.show()
    return xy

phiW=widgets.FloatSlider(min=-2*np.pi, max=2*np.pi, step=np.pi/16, value=0, continuous_update=False)
widgets.interact(phase,phi=phiW)

# %% [markdown]
# ## A vous de jouer !
#
# > **Q3.2** : Pour quelle valeur du déphasage obtient-on un signal somme d'amplitude maximale ?
#
# > **Q3.2-R** (votre réponse ici) :
#
# > **Q3.3** : Pour quelle valeur du déphasage obtient-on un signal somme d'amplitude nulle ?
#
# > **Q3.3-R** (votre réponse ici) :

# %% [markdown]
# ## II.4. Somme de deux sinusoïdes de fréquences multiples l'une de l'autre
#
# La somme de deux sinusoïdes de fréquences harmoniques (*i.e.* multiples l'une de l'autre, soit $\frac{f_1}{f_0}=n \in \mathbb{N}$) est toujours une sinusoïde de fréquence $f_0$. Vérifiez cette propriété à l'aide de la simulation ci-dessous, où vous pouvez également choisir le déphasage entre les deux sinusoïdes (entre 0 et $2\pi$ par intervalle de $\frac{\pi}{8}$.
#
# Cette propriété est à la base de la décomposition en série de Fourier, qui sera vue dans la section 2 de ce cours. La fréquence $f_0$ est appelée **fréquence fondamentale**, ses fréquences multiples les **harmoniques** (de rang $n$).

# %%
def somme1(fm1,deltaphi):
    A=1
    f0=1/(2*np.pi)
    f1=fm1*f0
    N=2**9
    tt=np.linspace(-1/f0,1/f0,N)
    dt=tt[1]-tt[0]
    x=np.sin(2*np.pi*f0*tt)
    y=np.sin(2*np.pi*f1*tt+deltaphi)
    z=x+y

    plt.plot(tt,x)
    plt.plot(tt,y)
    plt.plot(tt,z,'r',linewidth=3)
    plt.plot(0,0,'ob')
    plt.ylim(-2,2)

    plt.grid('On')
    plt.title('Somme de 2 sinusoïdes harmoniques')
    plt.xlabel('temps (s)')
    plt.ylabel('signaux')
    plt.legend(['x(t)','y(t)','x(t)+y(t)'])
    plt.show()
    
    print("f2 = %1.0f fois f1" %fm1)    #  Formatted output !
    dephi=deltaphi/np.pi
    print('Le déphasage est égal à %1.2f pi' %dephi) 


widgets.interact(somme1, fm1=widgets.IntSlider(min=0, max=10, value=2, description="f2/f1 ="), 
                deltaphi=widgets.FloatSlider(min=0, max=2*np.pi, value=0, step=np.pi/8, description="Déphasage"))

# %% [markdown]
# ## A vous de jouer !
#
# > **Q4.1** : Que vaut la période du signal somme ? Cette valeur est-elle dépendante du multiple $n$ ?
#
# > **Q4.1-R** (votre réponse ici) :
#
# > **Q4.2** : Cette valeur varie-t'elle lorsque vous changez le déphasage entre les deux sinusoïdes ? Qu'est-ce qui change dans ce cas ?
#
# > **Q4.2-R** (votre réponse ici) :
#
# > **Q4.3** : La propriété varie-t'elle lorsque $x(t)$ et $y(t)$ n'ont pas une amplitude égale (vérifiez en adaptant le script) ?
#
# > **Q4.3-R** (votre réponse ici) :
#
# > **Q4.4** : Modifiez le script Python ci-dessus pour calculer numériquement et afficher le résultat de la somme d'une sinusoïde de fréquence fondamentale $f_0$ et de N harmoniques affectées d'une amplitude $A_n=\frac{2}{n \pi}$. Comment appelle-t'on le signal résultant de la somme de la fondamentale et de ses harmoniques ?
#
# > **Q4.4-R** (votre réponse ici) :
#
# > **Q4.5** : Comment le signal est-il modifié lorsqu'on inverse le signe des amplitudes en prenant $A_n=\frac{-2}{n \pi}$ ?
#
# > **Q4.5-R** (votre réponse ici) :

# %% [markdown]
# ## II.5. Somme de deux sinusoïdes de fréquences proches : Battements
#
# Les musiciens de l'orchestre accordent leur instrument en écoutant les battements entre un signal sonore sinusoïdal $x(t)$ produit par leur instrument et un signal sinusoïdal $y(t)$ (un son pur) produit par une source émettant à la fréquence de référence.
#
# $$ \begin{align}
# x(t) + y(t) &= \ \sin(2\pi f_0t ) + \ \sin(2\pi f_1t + \phi) \\
# &= 2 \sin \left( \frac{2 \pi (f_0 + f_1) t + \phi}{2} \right) \cos \left( \frac{2 \pi (f_0-f_1) - \phi}{2} \right) \\
# &= A(t) \sin \left( \frac{2 \pi (f_0 + f_1) t + \phi}{2} \right)
# \end{align}
# $$
#
# La somme de ces sinusoïdes de fréquences $f_0$ et $f_1$ (la fréquence de référence) aboutit à un produit d'une sinusoïde à une fréquence élevée $f_+=f_0+f_1$ multipliée par une cosinusoïde de fréquence $f_-f_0-f_1$, d'autant plus faible que $f_0$ est proche de $f_1$. Ces deux composantes sont bien visibles sur la figure ci-dessous, où l'on voit que la cosinusoïde de fréquence faible $f_-$ agit comme une enveloppe $A(t)$ qui module l'amplitude instantanée de la sinusoïde de fréquence $f_+$.
#
# ![](https://raw.githubusercontent.com/Pango01/Signal00/main/Beating.png)
#
# Dans la cellule ci-dessous, programmez et visualisez la somme des signaux $x(t)$ (de fréquence $f_0$) et $y(t)$ de fréquence $f_1$. Utilisez un slider pour fixer dynamiquement la valeur de $f_1$ dans la figure.

# %%
N=12800
T0=5
   
t=np.arange(0,T0,T0/N)

te=T0/N
fe=1/te
f0max=fe/2

print('Sampling frequency =',fe)
print('Nyquist frequency =',fe/2)

A=1
# high frequency for sound hearing
f0=180
 
xy=np.zeros(N)
print('Frequency f0 =',f0)

def fa(f1):
    global xy
    x=A*np.cos(2*np.pi*f0*t)
    y=A*np.cos(2*np.pi*f1*t)
    xy=x+y
    plt.plot(t,x,'b',t,y,'g',t,xy,'r')
    plt.axis([0,4*25/f0,-2,2])
    plt.savefig('Beating.png')
    plt.show()
    return f1,xy

widgets.interact(fa, f1=f0+4);
f0W=widgets.IntSlider(min=f0*0.9, max=f0*1.1, step=1, value=f0, continuous_update=False)
widgets.interact(f1=f0W)

# Audio(xy,rate=fe)
# A placer dans une cellule suivante, sinon il joue f1=f0

# %% [markdown]
# Vous pouvez écouter le résultat des battements en exécutant la cellule ci-dessous, puis en cliquant sur le triangle du lecteur audio qui sera généré (attention au volume !).

# %%
Audio(xy,rate=fe)

# %% [markdown]
# ## A vous de jouer !
#
# > **Q5.1** : Comment varie la période de l'enveloppe lorsque $f_1$ se rapporche de $f_0$ ?
#
# > **Q5.1-R** (votre réponse ici) :
#
# > **Q5.2** : Que devient le signal somme lorsque $f_1=f_0$ ?
#
# > **Q5.2-R** (votre réponse ici) :
#
# > **Q5.3** : Mesurez la période apparente des battements pour $f_1-f_0=\{5,4,3,2,1,0\}$, et représentez ces points dans un graphe dans la cellule ci-dessous.
#
# -----------------------------

# %% [markdown]
# ### III.6. Accord d'un instrument de l'orchestre
#
# Les musiciens de l'orchestre accordent leur instrument en écoutant les battements entre un signal sonore sinusoïdal $x(t)$ produit par leur instrument et un signal sinusoïdal $y(t)$ (un son pur) produit par une source émettant à la fréquence de référence. Le script ci-dessous illustre de manière sonore la diminution de la fréquence des battements $f_0-f_1$ lorsque la fréquence $f_0$ émise par l'instrument à accorder s'approche de la fréquence de référence $f_1$.

# %%
N=12800
T0=4
   
t=np.arange(0,T0,T0/N)
te=T0/N
fe=1/te
f0max=fe/2

print('Sampling frequency =',fe)
print('Nyquist frequency =',fe/2)

A=0.5
f0=180
ff1=np.arange(f0+6,f0-1,-1)
# xy=np.zeros(np.size(t))
xy=np.zeros(2)
x=A*np.cos(2*np.pi*f0*t)

for f1 in ff1:
    y=A*np.cos(2*np.pi*f1*t)
    z=x+y
    xy=np.concatenate((xy,z))

plt.plot(xy,'r')
# plt.axis([0,4*25/f0,-2,2])
plt.savefig('Tuning.png')
plt.show()

Audio(xy,rate=fe)

# %% [markdown]
# ### II.7. Synthèse d'un signal périodique par série de Fourier
#
# Toute combinaison linéaire (*i.e.* une somme pondérée) de sinusoïdes de fréquences harmoniques (*i.e.* multiples d'une fréquence $f_0$, soit $\frac{f_1}{f_0}=n \in \mathbb{N}$) est un signal (une fonction) périodique (bien que non-sinusoïdale) de fréquence $f_0$ ; on parle de développement en **série de Fourier**, qui s'écrit en général :
#
# $$
# x(t) =  \sum_{k=1}^{+\infty} \left[ a_k \ \cos (2 \pi k f_0 t + \phi_k) + b_k \ \sin (2 \pi k f_0 t + \phi'_k) \right]
# $$
#
# La fréquence $f_0$ est appelée fréquence fondamentale, ses fréquences multiples les harmoniques (de rang $n$). En choisissant convenablement les coefficients du développement en série de Fourier ($a_k$ pour les cos et $b_k$ pour les sin) de la combinaison linéaire, on peut générer des signaux de forme particulière.

# %%
N=2**9
f0=1/(2*np.pi)
A=1

tt=np.linspace(-1/f0,1/f0,N)
dt=tt[1]-tt[0]
x=A*np.sin(2*np.pi*f0*tt)

def func1(kmax):
    km=np.arange(1,kmax)
    z=np.zeros(np.size(x))
    for k in km:
        f1=k*f0
        #  Définition des coefficients du développement en série de Fourier
        #A=(2/(np.pi*k))**2  
        A=2/(np.pi*k)    #  a sawtooth
        y=A*np.sin(2*np.pi*f1*tt)
        z=z+y
        
    plt.plot(tt,x)
    plt.plot(tt,z,'r',linewidth=3)
    plt.plot(0,0,'ob')

    plt.grid('On')
    Nharm=str(kmax-1)
    plt.title('Somme de '+Nharm+' sinusoïdes harmoniques')
    plt.xlabel('temps (s)')
    plt.ylabel('signaux')
    plt.legend(['x(t)','z(t)'])
    plt.show()

widgets.interact(func1, kmax=widgets.IntSlider(min=2, max=20, value=17,
                                               description="1+ Nombre d'harmoniques ="))

# %% [markdown]
# ## A vous de jouer !
#
# Dans le script ci-dessous, variez avec le slider le nombre total d'harmoniques du développement en série de Fourier, et voyez comment le signal résultant s'approche d'un signal en dents de scie.
#
# > **Q7.1** : Trouvez l'expression des coefficients qui inversent l'orientation du signal en dents de scie.
#
# > **Q7.1-R** (votre réponse ici) :
#
# > **Q7.2** : Modifiez la définition des coefficients des sinusoïdes en prenant $b_k = \left( \frac{2}{k \pi} \right)^2$.A quoi ressemble le signal ainsi généré ?
#
# > **Q7.2-R** (votre réponse ici) :
#
# > **Q7.3** : Recherchez sur Internet l'expression du développement en série de Fourier d'un signal que vous choisirez. Ajouter au script ci-dessus l'expression de ces coefficients $b_k$ (pour les sinusoïdes), et éventuellement $a_k$ (pour les COsinusoïdes), et retrouvez le signal recherché. Dequel type de signal s-agit-il ?
#
# > **Q7.3-R** (votre réponse ici) :
#
# > **Q7.4** : Dans le cas du développement en série de Fourier du signal en dents de scie, on constate la présence d'oscillations résiduelles, particulièrement marquées au voisinage des discontinuités, qui sont difficilement reproductibles à l'aide de fonctions (ou signaux) continues. Comment s'appellent ces oscillations ?
#
# > **Q7.4-R** (votre réponse ici) :

# %% [markdown]
# ------
#
# ## II.8. Conclusions personnelles
#
# Indiquez ci-dessous le temps approximatif que vous passé à travailler ce TP en-dehors de la séance.
#
# > Votre réponse ici :
#
# Ecrivez ci-dessous, en guise de conclusions, quelques phrases décrivant ce que ce TP vous a appris.
#
# > **Conclusions personnelles** (votre réponse ici) :
# ------
# ------
